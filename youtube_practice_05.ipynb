# %%
import numpy as np
from skimage import io
photo = io.imread('blue poles.jpg')
type(photo)
# Out:
# numpy.ndarray

# %%
 photo.shape
# Out:
# (1153, 1920, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(photo)

# %%
plt.imshow(photo[::-1])

# %%
plt.imshow(photo[50:150, 150:200])

# %%
plt.imshow(photo[::2, ::2])

# %%
photo
photo_sin = np.sin(photo)
photo_sin
# Out:
# array([[[-0.2793 , -0.757  ,  0.412  ],
#         [-0.757  ,  0.909  ,  0.657  ],
#         [ 0.909  ,  0.     , -0.959  ],
#         ...,
#         [ 0.     , -1.     ,  0.6504 ],
#         [ 0.     , -1.     ,  0.6504 ],
#         [ 0.     , -0.544  ,  0.9907 ]],
#
#        [[ 0.     ,  0.     , -0.959  ],
#         [ 0.     ,  0.     , -0.959  ],
#         [ 0.     ,  0.8413 , -0.2793 ],
#         ...,
#         [-0.959  , -0.757  ,  0.909  ],
#         [ 0.1411 ,  0.909  ,  0.     ],
#         [ 0.1411 ,  0.909  ,  0.     ]],
#
#        [[ 0.     ,  0.8413 , -0.757  ],
#         [ 0.     ,  0.8413 , -0.757  ],
#         [ 0.     ,  0.909  , -0.959  ],
#         ...,
#         [-0.3713 , -0.999  ,  0.0354 ],
#         [ 0.5806 , -0.573  , -0.822  ],
#         [ 0.999  ,  0.3796 , -0.822  ]],
#
#        ...,
#
#        [[ 0.2021 ,  0.9805 ,  0.927  ],
#         [-0.882  , -0.9985 , -0.8647 ],
#         [-0.4756 ,  0.933  ,  0.999  ],
#         ...,
#         [-0.5063 ,  0.33   , -0.882  ],
#         [-0.5063 ,  0.05304, -0.9785 ],
#         [ 0.1847 , -0.588  ,  0.7085 ]],
#
#        [[-0.727  , -0.6895 , -0.9746 ],
#         [-0.9956 , -0.9424 ,  0.9766 ],
#         [-0.3713 ,  0.8857 , -0.4756 ],
#         ...,
#         [-0.8013 ,  0.9395 ,  0.721  ],
#         [ 0.9976 , -0.602  , -0.228  ],
#         [ 0.3467 ,  0.9976 ,  0.05307]],
#
#        [[-0.9956 ,  0.566  , -0.9917 ],
#         [-0.616  ,  0.9995 ,  0.964  ],
#         [-0.9956 ,  0.566  ,  0.745  ],
#         ...,
#         [-0.8735 , -0.355  ,  0.8066 ],
#         [-0.8735 , -0.355  ,  0.8066 ],
#         [-0.0619 , -0.9785 , -0.06192]]], dtype=float16)

# %%
print(np.sum(photo))
print(np.prod(photo))
print(np.mean(photo))
print(np.std(photo))
print(np.var(photo))
print(np.min(photo))
print(np.max(photo))
print(np.argmin(photo))
print(np.argmax(photo))
# Out:
# 739043765
# 0
# 111.28032020935723
# 74.47484663463004
# 5546.5027812516655
# 0
# 255
# 7
# 22785

# %%
z = np.array([1, 2, 3, 4, 5])

# %%
z < 3
# Out:
# array([ True,  True, False, False, False])

# %%
z > 3
# Out:
# array([False, False, False,  True,  True])

# %%
z[z > 3]
# Out:
# array([4, 5])

# %%
photo_masked = np.where(photo > 100, 255, 0)

# %%
plt.imshow(photo_masked)

# %%
a_array = np.array([1, 2, 3, 4, 5])
b_array = np.array([6, 7, 8, 9, 10])

# %%
a_array + b_array
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
a_array + 30
# Out:
# array([31, 32, 33, 34, 35])

# %%
a_array + b_array
# Out:
# array([ 7,  9, 11, 13, 15])

# %%
a_array + 10
# Out:
# array([11, 12, 13, 14, 15])

# %%
a_array @ b_array
# Out:
# 130

# %%
plt.imshow(photo[:,:,0].T)

# %%
x = np.array([2, 1, 4, 3, 5])
np.sort(x)
# Out:
# array([1, 2, 3, 4, 5])
